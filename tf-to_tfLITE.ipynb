# %%
import tensorflow as tf
from tensorflow import keras

tf.__version__
# Out:
# '2.7.0'

# %%
# load image with keras-image kelper
# !pip install keras-image-helper ; ! pip install --extra-index-url https://google-coral.github.io/py-repo/tflite_runtime
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras-image-helper in /home/elegant00/.local/lib/python3.9/site-packages (0.0.1)
# Requirement already satisfied: numpy in /home/elegant00/.local/lib/python3.9/site-packages (from keras-image-helper) (1.19.5)
# Requirement already satisfied: pillow in /usr/lib/python3.9/site-packages (from keras-image-helper) (8.4.0)
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: You must give at least one requirement to install (see "pip help install")

# %%
#import tensorflow.lite as tflite
import tflite_runtime.interpreter as tflite
from keras_image_helper import create_preprocessor

# %%
interpreter = tflite.Interpreter(model_path='models/XCeption_V1_Fruits.tflite')
interpreter.allocate_tensors()


input_index = interpreter.get_input_details()[0]['index']
output_index = interpreter.get_output_details()[0]['index']

# %%
preprocessor = create_preprocessor('xception', target_size=(100, 100))
url = 'https://i.imgur.com/Wj4Lajm.png' # image of a banana I downloaded from Google
X = preprocessor.from_url(url)

# %% [markdown]
# ### (For Reference) Image to classify:

# %% [markdown]
# ![banana_image](https://i.imgur.com/Wj4Lajm.png)

# %%
interpreter.set_tensor(input_index, X)
interpreter.invoke()
preds = interpreter.get_tensor(output_index)

# %%
classes = ['Apple Braeburn',
 'Apple Crimson Snow',
 'Apple Golden 1',
 'Apple Golden 2',
 'Apple Golden 3',
 'Apple Granny Smith',
 'Apple Pink Lady',
 'Apple Red 1',
 'Apple Red 2',
 'Apple Red 3',
 'Apple Red Delicious',
 'Apple Red Yellow 1',
 'Apple Red Yellow 2',
 'Apricot',
 'Avocado',
 'Avocado ripe',
 'Banana',
 'Banana Lady Finger',
 'Banana Red',
 'Beetroot',
 'Blueberry',
 'Cactus fruit',
 'Cantaloupe 1',
 'Cantaloupe 2',
 'Carambula',
 'Cauliflower',
 'Cherry 1',
 'Cherry 2',
 'Cherry Rainier',
 'Cherry Wax Black',
 'Cherry Wax Red',
 'Cherry Wax Yellow',
 'Chestnut',
 'Clementine',
 'Cocos',
 'Corn',
 'Corn Husk',
 'Cucumber Ripe',
 'Cucumber Ripe 2',
 'Dates',
 'Eggplant',
 'Fig',
 'Ginger Root',
 'Granadilla',
 'Grape Blue',
 'Grape Pink',
 'Grape White',
 'Grape White 2',
 'Grape White 3',
 'Grape White 4',
 'Grapefruit Pink',
 'Grapefruit White',
 'Guava',
 'Hazelnut',
 'Huckleberry',
 'Kaki',
 'Kiwi',
 'Kohlrabi',
 'Kumquats',
 'Lemon',
 'Lemon Meyer',
 'Limes',
 'Lychee',
 'Mandarine',
 'Mango',
 'Mango Red',
 'Mangostan',
 'Maracuja',
 'Melon Piel de Sapo',
 'Mulberry',
 'Nectarine',
 'Nectarine Flat',
 'Nut Forest',
 'Nut Pecan',
 'Onion Red',
 'Onion Red Peeled',
 'Onion White',
 'Orange',
 'Papaya',
 'Passion Fruit',
 'Peach',
 'Peach 2',
 'Peach Flat',
 'Pear',
 'Pear 2',
 'Pear Abate',
 'Pear Forelle',
 'Pear Kaiser',
 'Pear Monster',
 'Pear Red',
 'Pear Stone',
 'Pear Williams',
 'Pepino',
 'Pepper Green',
 'Pepper Orange',
 'Pepper Red',
 'Pepper Yellow',
 'Physalis',
 'Physalis with Husk',
 'Pineapple',
 'Pineapple Mini',
 'Pitahaya Red',
 'Plum',
 'Plum 2',
 'Plum 3',
 'Pomegranate',
 'Pomelo Sweetie',
 'Potato Red',
 'Potato Red Washed',
 'Potato Sweet',
 'Potato White',
 'Quince',
 'Rambutan',
 'Raspberry',
 'Redcurrant',
 'Salak',
 'Strawberry',
 'Strawberry Wedge',
 'Tamarillo',
 'Tangelo',
 'Tomato 1',
 'Tomato 2',
 'Tomato 3',
 'Tomato 4',
 'Tomato Cherry Red',
 'Tomato Heart',
 'Tomato Maroon',
 'Tomato Yellow',
 'Tomato not Ripened',
 'Walnut',
 'Watermelon']

# %%
d= dict(zip(classes, preds[0]))

sorted(d.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('Banana', 0.99978906),
#  ('Banana Lady Finger', 0.00021091342),
#  ('Pepper Yellow', 4.6355936e-12),
#  ('Banana Red', 4.2854714e-13),
#  ('Tomato 2', 6.718908e-14),
#  ('Cucumber Ripe', 7.4093376e-16),
#  ('Tomato 1', 1.5208825e-16),
#  ('Pepper Orange', 1.3305511e-16),
#  ('Pepino', 1.0719866e-16),
#  ('Cherry Wax Black', 5.8765114e-17),
#  ('Pear 2', 5.3177423e-17),
#  ('Carambula', 2.7126407e-17),
#  ('Apple Golden 2', 1.1616474e-17),
#  ('Tomato Cherry Red', 1.797801e-18),
#  ('Grape White', 1.5404414e-18),
#  ('Rambutan', 6.349996e-19),
#  ('Physalis', 5.4531965e-19),
#  ('Cherry Rainier', 2.0321216e-19),
#  ('Mulberry', 1.7453682e-19),
#  ('Tomato 4', 1.5020322e-19),
#  ('Clementine', 4.007167e-20),
#  ('Strawberry Wedge', 3.1941583e-20),
#  ('Grape White 3', 1.5804753e-20),
#  ('Grapefruit Pink', 1.1449062e-20),
#  ('Avocado ripe', 8.2642104e-21),
#  ('Cherry 2', 7.762561e-21),
#  ('Corn Husk', 7.323585e-21),
#  ('Raspberry', 7.052379e-21),
#  ('Pepper Red', 6.91207e-21),
#  ('Cherry 1', 6.832792e-21),
#  ('Pepper Green', 4.7213963e-21),
#  ('Tomato Yellow', 2.260896e-21),
#  ('Tomato 3', 1.5914431e-21),
#  ('Pear Abate', 1.3403953e-21),
#  ('Cherry Wax Yellow', 9.68549e-22),
#  ('Redcurrant', 6.3172966e-22),
#  ('Cantaloupe 1', 5.131226e-22),
#  ('Eggplant', 5.043663e-22),
#  ('Corn', 4.7585145e-22),
#  ('Nut Pecan', 4.7152203e-22),
#  ('Physalis with Husk', 3.5512062e-22),
#  ('Tamarillo', 3.1184255e-22),
#  ('Grape Blue', 2.5071022e-22),
#  ('Cherry Wax Red', 2.3883909e-22),
#  ('Apple Red Delicious', 2.0815393e-22),
#  ('Lychee', 1.6736104e-22),
#  ('Grape White 2', 1.423825e-22),
#  ('Chestnut', 9.478932e-23),
#  ('Peach 2', 8.17871e-23),
#  ('Apple Red 2', 7.785387e-23),
#  ('Quince', 6.793437e-23),
#  ('Kaki', 6.331503e-23),
#  ('Salak', 5.83499e-23),
#  ('Watermelon', 5.616681e-23),
#  ('Plum 3', 3.1104994e-23),
#  ('Kumquats', 2.671209e-23),
#  ('Tangelo', 1.9666528e-23),
#  ('Apricot', 1.90083e-23),
#  ('Mandarine', 1.7923799e-23),
#  ('Hazelnut', 1.4848472e-23),
#  ('Melon Piel de Sapo', 1.2996599e-23),
#  ('Pitahaya Red', 9.982492e-24),
#  ('Apple Pink Lady', 7.696589e-24),
#  ('Huckleberry', 4.2511087e-24),
#  ('Dates', 2.544192e-24),
#  ('Cucumber Ripe 2', 1.5979314e-24),
#  ('Potato Red Washed', 1.0366571e-24),
#  ('Apple Granny Smith', 7.010414e-25),
#  ('Pineapple Mini', 5.848132e-25),
#  ('Grape White 4', 3.7701955e-25),
#  ('Lemon Meyer', 1.5137967e-25),
#  ('Apple Braeburn', 1.3558616e-25),
#  ('Granadilla', 1.0381803e-25),
#  ('Cantaloupe 2', 1.0375626e-25),
#  ('Maracuja', 9.249418e-26),
#  ('Nectarine', 8.8094415e-26),
#  ('Apple Golden 3', 6.818845e-26),
#  ('Grapefruit White', 6.472622e-26),
#  ('Pear Williams', 6.229791e-26),
#  ('Tomato Heart', 4.2842826e-26),
#  ('Cauliflower', 3.2550857e-26),
#  ('Passion Fruit', 2.1285573e-26),
#  ('Orange', 2.1017054e-26),
#  ('Pear Monster', 1.4600803e-26),
#  ('Apple Red 1', 1.4291767e-26),
#  ('Ginger Root', 1.1987954e-26),
#  ('Avocado', 6.770657e-27),
#  ('Apple Red Yellow 1', 5.9781836e-27),
#  ('Peach Flat', 4.9935115e-27),
#  ('Papaya', 3.5930715e-27),
#  ('Pear Forelle', 3.591372e-27),
#  ('Apple Golden 1', 1.734873e-27),
#  ('Plum 2', 1.2723627e-27),
#  ('Strawberry', 6.7499444e-28),
#  ('Pear Kaiser', 4.3770186e-28),
#  ('Pear Stone', 4.0459195e-28),
#  ('Walnut', 3.0669556e-28),
#  ('Pear Red', 1.4730466e-28),
#  ('Mango Red', 1.3848553e-28),
#  ('Fig', 1.3399558e-28),
#  ('Tomato Maroon', 1.2217577e-28),
#  ('Cocos', 1.0925726e-28),
#  ('Pear', 8.4066246e-29),
#  ('Onion Red Peeled', 7.77901e-29),
#  ('Pineapple', 6.608007e-29),
#  ('Pomelo Sweetie', 5.5215334e-29),
#  ('Peach', 4.8139835e-29),
#  ('Apple Red Yellow 2', 3.106624e-29),
#  ('Blueberry', 2.4345136e-29),
#  ('Mango', 2.2655143e-29),
#  ('Apple Crimson Snow', 1.8594142e-29),
#  ('Pomegranate', 1.7607802e-29),
#  ('Nectarine Flat', 1.11142566e-29),
#  ('Plum', 1.0644857e-29),
#  ('Apple Red 3', 8.399856e-30),
#  ('Potato Sweet', 6.328365e-30),
#  ('Mangostan', 3.1971897e-30),
#  ('Grape Pink', 2.2975848e-30),
#  ('Limes', 2.0155194e-30),
#  ('Lemon', 1.057092e-30),
#  ('Beetroot', 3.0656293e-31),
#  ('Nut Forest', 5.249317e-32),
#  ('Kohlrabi', 3.9620296e-32),
#  ('Guava', 3.9384015e-32),
#  ('Kiwi', 7.168204e-33),
#  ('Onion Red', 5.2776045e-33),
#  ('Cactus fruit', 1.1678226e-33),
#  ('Tomato not Ripened', 1.1153989e-33),
#  ('Potato Red', 4.410695e-34),
#  ('Potato White', 1.4368018e-34),
#  ('Onion White', 1.1467501e-36)]
